# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel('/content/apple_quality.xlsx')

# %%
df
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
# 4000     NaN       NaN       NaN        NaN          NaN        NaN       NaN
#
# ...

# %%
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#     Acidity Quality
# 0  -0.49159    good
# 1 -0.722809    good
# 2  2.621636     bad
# 3  0.790723    good
# 4  0.501984    good

# %%
df = df.iloc[:-1]  # Removes the last row

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4000 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
df.describe()
# Out:
#               A_id         Size       Weight    Sweetness  Crunchiness  \
# count  4000.000000  4000.000000  4000.000000  4000.000000  4000.000000
# mean   1999.500000    -0.503015    -0.989547    -0.470479     0.985478
# std    1154.844867     1.928059     1.602507     1.943441     1.402757
# min       0.000000    -7.151703    -7.149848    -6.894485    -6.055058
# 25%     999.750000    -1.816765    -2.011770    -1.738425     0.062764
# 50%    1999.500000    -0.513703    -0.984736    -0.504758     0.998249
# 75%    2999.250000     0.805526     0.030976     0.801922     1.894234
# max    3999.000000     6.406367     5.790714     6.374916     7.619852
#
#          Juiciness     Ripeness
# count  4000.000000  4000.000000
# mean      0.512118     0.498277
# std       1.930286     1.874427
# min      -5.961897    -5.864599
# 25%      -0.801286    -0.771677
# 50%       0.534219     0.503445
# 75%       1.835976     1.766212
# max       7.364403     7.237837

# %%
df.isnull().sum()
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
df.tail()
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#        Acidity Quality
# 3995  0.137784     bad
# 3996  1.854235    good
# 3997 -1.334611     bad
# 3998  -2.22972    good
# 3999  1.599796    good

# %% [markdown]
# Initial Observations:
#
# The dataset contains 4000 rows and 9 columns.
#
# There are no missing values in the columns A_id, Size, Weight, Sweetness,
# Crunchiness, Juiciness, Ripeness, and Quality.
#
# The target variable "Quality" is categorical with values like "good" and "bad".

# %%
df.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
q1=df.Size.quantile(0.25)
q3=df.Size.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Size']=[min if x<min else max if x>max else x for x in df['Size']]
# Out:
# <ipython-input-29-3477dfa0b7ea>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size']=[min if x<min else max if x>max else x for x in df['Size']]

# %%
q1=df.Weight.quantile(0.25)
q3=df.Weight.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Weight']=[min if x<min else max if x>max else x for x in df['Weight']]
# Out:
# <ipython-input-15-1be9f0e59057>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight']=[min if x<min else max if x>max else x for x in df['Weight']]

# %%
q1=df.Sweetness.quantile(0.25)
q3=df.Sweetness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Sweetness']=[min if x<min else max if x>max else x for x in df['Sweetness']]
# Out:
# <ipython-input-16-0b5896e07cca>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sweetness']=[min if x<min else max if x>max else x for x in df['Sweetness']]

# %%
q1=df.Crunchiness.quantile(0.25)
q3=df.Crunchiness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Crunchiness']=[min if x<min else max if x>max else x for x in df['Crunchiness']]
# Out:
# <ipython-input-17-e0741b6d3af4>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Crunchiness']=[min if x<min else max if x>max else x for x in df['Crunchiness']]

# %%
q1=df.Juiciness.quantile(0.25)
q3=df.Juiciness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Juiciness']=[min if x<min else max if x>max else x for x in df['Juiciness']]
# Out:
# <ipython-input-18-6de53a02a956>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Juiciness']=[min if x<min else max if x>max else x for x in df['Juiciness']]

# %%
q1=df.Ripeness.quantile(0.25)
q3=df.Ripeness.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Ripeness']=[min if x<min else max if x>max else x for x in df['Ripeness']]
# Out:
# <ipython-input-19-46fb937c602b>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ripeness']=[min if x<min else max if x>max else x for x in df['Ripeness']]

# %%
q1=df.Acidity.quantile(0.25)
q3=df.Acidity.quantile(0.75)
IQR=q3-q1
min=q1-1.5*(IQR)
max=q3+1.5*(IQR)
df['Acidity']=[min if x<min else max if x>max else x for x in df['Acidity']]
# Out:
# <ipython-input-20-3b6cd44c6d64>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Acidity']=[min if x<min else max if x>max else x for x in df['Acidity']]

# %% [markdown]
# ### Univariate Analysis

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x=df["Quality"], palette="Set2")
plt.title("Quality Distribution")
plt.xlabel("Quality")
plt.ylabel("Count")
plt.show()
# Out:
# <ipython-input-22-c6ca59f4119b>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df["Quality"], palette="Set2")

# %% [markdown]
# The dataset is nearly balanced, with a slight dominance of "good" apples over "bad" ones.

# %%
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Feature Distributions by Apple Quality", fontsize=16)

sns.boxplot(x=df["Quality"], y=df["Size"], ax=axes[0, 0], palette="Set2")
axes[0, 0].set_title("Size vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Weight"], ax=axes[0, 1], palette="Set2")
axes[0, 1].set_title("Weight vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Sweetness"], ax=axes[0, 2], palette="Set2")
axes[0, 2].set_title("Sweetness vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Crunchiness"], ax=axes[1, 0], palette="Set2")
axes[1, 0].set_title("Crunchiness vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Juiciness"], ax=axes[1, 1], palette="Set2")
axes[1, 1].set_title("Juiciness vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Ripeness"], ax=axes[1, 2], palette="Set2")
axes[1, 2].set_title("Ripeness vs. Quality")

sns.boxplot(x=df["Quality"], y=df["Acidity"], ax=axes[2, 0], palette="Set2")
axes[2, 0].set_title("Acidity vs. Quality")



plt.show()
# Out:
# <ipython-input-38-16fce8256c64>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Quality"], y=df["Size"], ax=axes[0, 0], palette="Set2")
# <ipython-input-38-16fce8256c64>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Quality"], y=df["Weight"], ax=axes[0, 1], palette="Set2")
# <ipython-input-38-16fce8256c64>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df["Quality"], y=df["Sweetness"], ax=axes[0, 2], palette="Set2")
# <ipython-input-38-16fce8256c64>:13: FutureWarning:
#
# ...

# %% [markdown]
# 1.   Bigger and heavier apples are generally of better quality.
# 2.   Sweeter, crunchier, and juicier apples are more likely to be "Good."
# 3.   Ripeness matters, but both underripe and overripe apples exist in the "Bad" category.
# 4.  Acidity doesn’t seem to impact quality much.

# %%
# Correlation matrix for numeric features only
numeric_df = df.select_dtypes(include=np.number)
plt.figure(figsize=(10, 6))
sns.heatmap(numeric_df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Feature Correlation Heatmap (Numeric Features)")
plt.show()

# %%
df['Quality'].value_counts()
# Out:
# Quality
# good    2004
# bad     1996
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df["Quality"] = label_encoder.fit_transform(df["Quality"])
# Out:
# <ipython-input-43-64ae3842e70e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Quality"] = label_encoder.fit_transform(df["Quality"])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(df.drop(["A_id", "Quality"],axis=1),df['Quality'],test_size=0.3,random_state=0)
X_train.shape,X_test.shape
# Out:
# ((2800, 7), (1200, 7))

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
log_reg = LogisticRegression()
log_reg.fit(X_train_scaled, y_train)
y_pred = log_reg.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("Classification Report:\n", classification_rep)
# Out:
# Accuracy: 0.7283
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.74      0.72      0.73       612
#            1       0.71      0.74      0.73       588
#
#     accuracy                           0.73      1200
#    macro avg       0.73      0.73      0.73      1200
# weighted avg       0.73      0.73      0.73      1200

# %%
from sklearn.metrics import confusion_matrix

conf_matrix = confusion_matrix(y_test, y_pred)

conf_matrix_df = pd.DataFrame(conf_matrix,
                              index=["Actual Bad", "Actual Good"],
                              columns=["Predicted Bad", "Predicted Good"])
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='YlGnBu')

print(conf_matrix_df)
# Out:
#              Predicted Bad  Predicted Good
# Actual Bad             438             174
# Actual Good            152             436

# %% [markdown]
# ###Model Evaluation
# The model was evaluated on the test set using the following metrics:
#
# ## Accuracy Score
# The overall accuracy of the model was 72%, meaning the model correctly classified apple quality in a significant portion of test cases.
#
# ## Classification Report
# The classification report provides insights into precision, recall, and F1-score for each class:
#
#     Metric	Class 0 (Bad)	Class 1 (Good)
#     Precision	0.74	0.71
#     Recall	0.72	0.74
#     F1-Score	0.73	0.73
#     Support	612	588
# Precision: Indicates the proportion of correct predictions for each class.
#
# Recall: Measures the ability of the model to capture all relevant instances.
#
# F1-Score: Harmonic mean of precision and recall, providing a balance between the two.

# %% [markdown]
# ### Support Vector Classifier

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
svm_model = SVC(kernel="rbf", C=1.0, random_state=42)
svm_model.fit(X_train_scaled, y_train)


y_pred = svm_model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_pred)
classification_rep = classification_report(y_test, y_pred)
conf_matrix = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print("\nClassification Report:\n", classification_rep)
conf_matrix_df= pd.DataFrame(conf_matrix,
      index=["Actual Bad", "Actual Good"],
      columns=["Predicted Bad", "Predicted Good"])
print(conf_matrix_df)
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# Accuracy: 0.8800
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.90      0.86      0.88       612
#            1       0.86      0.90      0.88       588
#
#     accuracy                           0.88      1200
#    macro avg       0.88      0.88      0.88      1200
# weighted avg       0.88      0.88      0.88      1200
#
#              Predicted Bad  Predicted Good
# Actual Bad             527              85
# Actual Good             59             529
# <Axes: >

# %% [markdown]
# ### Model Evaluation
# The model was evaluated on the test set using various metrics:
#
# ## Accuracy Score
# The model achieved an accuracy of 88%.
#
# This indicates the percentage of correctly classified apples in the test set.
#
# ## Classification Report
#     Metric	Class 0 (Bad)	Class 1 (Good)
#     Precision	        0.90	0.86
#     Recall	          0.86	0.90
#     F1-Score	        0.88	0.88
#     Support            612	588

# %% [markdown]
# ### RandomForest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)

accuracy_rf = accuracy_score(y_test, y_pred)
classification_rep_rf = classification_report(y_test, y_pred, output_dict=True)
conf_matrix_rf = confusion_matrix(y_test, y_pred)

print(f"Accuracy: {accuracy_rf:.4f}")

print("\nClassification Report:")
print(classification_rep_rf['0'])
print(classification_rep_rf['1'])
# Out:
# Accuracy: 0.8800
#
# Classification Report:
# {'precision': 0.8993174061433447, 'recall': 0.8611111111111112, 'f1-score': 0.8797996661101837, 'support': 612.0}
# {'precision': 0.8615635179153095, 'recall': 0.8996598639455783, 'f1-score': 0.8801996672212978, 'support': 588.0}
#
# Confusion Matrix:
# TP: 529, FP: 85, FN: 59, TN: 527

# %%
print("\nConfusion Matrix:")
conf_matrix_df= pd.DataFrame(conf_matrix_rf,
      index=["Actual Bad", "Actual Good"],
      columns=["Predicted Bad", "Predicted Good"])
print(conf_matrix_df)
sns.heatmap(conf_matrix_df, annot=True, fmt='d', cmap='YlGnBu')
# Out:
# Confusion Matrix:
#              Predicted Bad  Predicted Good
# Actual Bad             527              85
# Actual Good             59             529
# <Axes: >
